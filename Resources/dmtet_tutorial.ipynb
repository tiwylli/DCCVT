# %% [markdown]
# # Reconstructing Point Cloud with DMTet
#
# Deep Marching Tetrahedra (DMTet) is a hybrid 3D representation that combines both implicit and explicit 3D surface representations. It represents a shape with a discrete SDF defined on vertices of a deformable tetrahedral grid. The SDF is converted to triangular mesh using a differentiable marching tetrahedra layer (MT), allowing explicit supervision on the extracted surface to be back-propagated to SDF and change mesh topology. In this tutorial, we demonstrate this by optimizing DMTet to reconstruct point cloud by minimizing the Chamfer Distance. The key functions used in this tutorial are in `kaolin.ops.conversions.trianglemesh`. See detailed [API documentation](https://kaolin.readthedocs.io/en/latest/modules/kaolin.ops.conversions.html#kaolin-ops-conversions).

# %%
import torch
import kaolin
import numpy as np
from dmtet_network import Decoder

# path to the point cloud to be reconstructed
#pcd_path = "../samples/bear_pointcloud.usd"
#pcd_path = "../data/bear_pointcloud.usd"
#pcd_path = "../data/32770.usd"
pcd_path = "../data/eabxhqb82fxu.usd"
# path to the output logs (readable with the training visualizer in the omniverse app)
logs_path = '../logs/'

# We initialize the timelapse that will store USD for the visualization apps
timelapse = kaolin.visualize.Timelapse(logs_path)

# %%
# arguments and hyperparameters
device = 'cuda'
lr = 1e-3
laplacian_weight = 0.1
iterations = 50000
save_every = 100
multires = 2
grid_res = 128

# %% [markdown]
# # Loading Point Cloud
#
# In this example, we use the point cloud generated by [Omniverse Kaolin App](https://docs.omniverse.nvidia.com/app_kaolin/app_kaolin/user_manual.html#data-generator). We load the pre-generated point cloud in `examples/samples/` and normalize it to the range of the tetrahedral grid. The normalized point cloud is saved to the checkpoint which can be visualized using [the Omniverse app](https://docs.omniverse.nvidia.com/app_kaolin/app_kaolin).

# %%
points = kaolin.io.usd.import_pointclouds(pcd_path)[0].points.to(device)
if points.shape[0] > 100000:
    idx = list(range(points.shape[0]))
    np.random.shuffle(idx)
    idx = torch.tensor(idx[:100000], device=points.device, dtype=torch.long)    
    points = points[idx]

# The reconstructed object needs to be slightly smaller than the grid to get watertight surface after MT.
points = kaolin.ops.pointcloud.center_points(points.unsqueeze(0), normalize=True).squeeze(0) * 0.9
timelapse.add_pointcloud_batch(category='input',
                               pointcloud_list=[points.cpu()], points_type = "usd_geom_points")

# %% [markdown]
# # Loading the Tetrahedral Grid
#
# DMTet starts from a uniform tetrahedral grid of predefined resolution, and uses a network to predict the SDF value as well as deviation vector at each grid vertex.
#
# Here we load the pre-generated tetrahedral grid using [Quartet](https://github.com/crawforddoran/quartet) at resolution 128, which has roughly the same number of vertices as a voxel grid of resolution 65. We use a simple MLP + positional encoding to predict the SDF and deviation vectors in DMTet, and initialize the encoded SDF to represent a sphere.

# %%
# tet_verts = torch.tensor(np.load('../samples/{}_verts.npz'.format(grid_res))['data'], dtype=torch.float, device=device)
tet_verts = torch.tensor(np.load('../data/{}_verts.npz'.format(grid_res))['data'], dtype=torch.float, device=device)
# tets = torch.tensor(([np.load('../samples/{}_tets_{}.npz'.format(grid_res, i))['data'] for i in range(4)]), dtype=torch.long, device=device).permute(1,0)
tets = torch.tensor(([np.load('../data/{}_tets_{}.npz'.format(grid_res, i))['data'] for i in range(4)]), dtype=torch.long, device=device).permute(1,0)

print (tet_verts.shape, tets.shape)

# Initialize model and create optimizer
model = Decoder(multires=multires).to(device)
model.pre_train_sphere(1000)
# Out:
# /tmp/ipykernel_41239/3382868736.py:4: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1678402412426/work/torch/csrc/utils/tensor_new.cpp:245.)
#   tets = torch.tensor(([np.load('../data/{}_tets_{}.npz'.format(grid_res, i))['data'] for i in range(4)]), dtype=torch.long, device=device).permute(1,0)
# torch.Size([277410, 3]) torch.Size([1524684, 4])
# Initialize SDF to sphere
# 100%|██████████| 1000/1000 [00:00<00:00, 1237.04it/s]
# Pre-trained MLP 7.454838396370178e-06

# %% [markdown]
# # Preparing the Losses and Regularizer
#
# During training we will use two losses defined on the surface mesh:
# - We use Chamfer Distance as the reconstruction loss. At each step, we randomly sample points from the surface mesh and compute the point-to-point distance to the GT point cloud.
# - DMTet can employ direct regularization on the surface mesh to impose useful geometric constraints. We demonstrate this with a Laplacian loss which encourages the surface to be smooth.

# %%
# Laplacian regularization using umbrella operator (Fujiwara / Desbrun).
# https://mgarland.org/class/geom04/material/smoothing.pdf
def laplace_regularizer_const(mesh_verts, mesh_faces):
    term = torch.zeros_like(mesh_verts)
    norm = torch.zeros_like(mesh_verts[..., 0:1])

    v0 = mesh_verts[mesh_faces[:, 0], :]
    v1 = mesh_verts[mesh_faces[:, 1], :]
    v2 = mesh_verts[mesh_faces[:, 2], :]

    term.scatter_add_(0, mesh_faces[:, 0:1].repeat(1,3), (v1 - v0) + (v2 - v0))
    term.scatter_add_(0, mesh_faces[:, 1:2].repeat(1,3), (v0 - v1) + (v2 - v1))
    term.scatter_add_(0, mesh_faces[:, 2:3].repeat(1,3), (v0 - v2) + (v1 - v2))

    two = torch.ones_like(v0) * 2.0
    norm.scatter_add_(0, mesh_faces[:, 0:1], two)
    norm.scatter_add_(0, mesh_faces[:, 1:2], two)
    norm.scatter_add_(0, mesh_faces[:, 2:3], two)

    term = term / torch.clamp(norm, min=1.0)

    return torch.mean(term**2)

def loss_f(mesh_verts, mesh_faces, points, it):
    pred_points = kaolin.ops.mesh.sample_points(mesh_verts.unsqueeze(0), mesh_faces, 50000)[0][0]
    chamfer = kaolin.metrics.pointcloud.chamfer_distance(pred_points.unsqueeze(0), points.unsqueeze(0)).mean()
    if it > iterations//2:
        lap = laplace_regularizer_const(mesh_verts, mesh_faces)
        return chamfer + lap * laplacian_weight
    return chamfer

# %% [markdown]
# # Setting up Optimizer

# %%
vars = [p for _, p in model.named_parameters()]
optimizer = torch.optim.Adam(vars, lr=lr)
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda x: max(0.0, 10**(-x*0.0002))) # LR decay over time

# %% [markdown]
# # Training
#
# At every iteration, we first predict SDF and deviation vector at each vertex with the network. Next, we extract the triangular mesh by running Marching Tetrahedra on the grid. We then compute loss functions on the extracted mesh and backpropagate gradient to the network weights. Notice that the topology of the mesh is changing during training, as shown in the output message. The training takes ~5 minutes on a TITAN RTX GPU.

# %%
for it in range(iterations):
    pred = model(tet_verts) # predict SDF and per-vertex deformation
    sdf, deform = pred[:,0], pred[:,1:]
    verts_deformed = tet_verts + torch.tanh(deform) / grid_res # constraint deformation to avoid flipping tets
    mesh_verts, mesh_faces = kaolin.ops.conversions.marching_tetrahedra(verts_deformed.unsqueeze(0), tets, sdf.unsqueeze(0)) # running MT (batched) to extract surface mesh
    mesh_verts, mesh_faces = mesh_verts[0], mesh_faces[0]
 
    loss = loss_f(mesh_verts, mesh_faces, points, it)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    scheduler.step()
    if (it) % save_every == 0 or it == (iterations - 1): 
        print ('Iteration {} - loss: {}, # of mesh vertices: {}, # of mesh faces: {}'.format(it, loss, mesh_verts.shape[0], mesh_faces.shape[0]))
        # save reconstructed mesh
        timelapse.add_mesh_batch(
            iteration=it+1,
            category='extracted_mesh',
            vertices_list=[mesh_verts.cpu()],
            faces_list=[mesh_faces.cpu()]
        )
# Out:
# Iteration 0 - loss: 0.017155790701508522, # of mesh vertices: 18106, # of mesh faces: 36208
# Iteration 100 - loss: 0.003119005588814616, # of mesh vertices: 20351, # of mesh faces: 40476
# Iteration 200 - loss: 0.0022261650301516056, # of mesh vertices: 22666, # of mesh faces: 45130
# Iteration 300 - loss: 0.0020593630615621805, # of mesh vertices: 23680, # of mesh faces: 47290
# Iteration 400 - loss: 0.0007149997400119901, # of mesh vertices: 31520, # of mesh faces: 63044
# Iteration 500 - loss: 0.0003421362489461899, # of mesh vertices: 34892, # of mesh faces: 69824
# Iteration 600 - loss: 0.00023881281958892941, # of mesh vertices: 35856, # of mesh faces: 71756
# Iteration 700 - loss: 0.00016957829939201474, # of mesh vertices: 36294, # of mesh faces: 72604
# Iteration 800 - loss: 0.0001523560204077512, # of mesh vertices: 36564, # of mesh faces: 73160
# Iteration 900 - loss: 0.0002468122402206063, # of mesh vertices: 35488, # of mesh faces: 71024
# Iteration 1000 - loss: 0.00018112956604454666, # of mesh vertices: 38066, # of mesh faces: 76128
# Iteration 1100 - loss: 0.00010074694000650197, # of mesh vertices: 37552, # of mesh faces: 75124
# Iteration 1200 - loss: 9.668886923464015e-05, # of mesh vertices: 37954, # of mesh faces: 75912
# Iteration 1300 - loss: 8.713085844647139e-05, # of mesh vertices: 37978, # of mesh faces: 75964
# Iteration 1400 - loss: 8.118117693811655e-05, # of mesh vertices: 38230, # of mesh faces: 76472
# Iteration 1500 - loss: 9.871000656858087e-05, # of mesh vertices: 38358, # of mesh faces: 76720
# Iteration 1600 - loss: 7.38487797207199e-05, # of mesh vertices: 38404, # of mesh faces: 76816
# Iteration 1700 - loss: 0.00010580859088804573, # of mesh vertices: 38642, # of mesh faces: 77280
# Iteration 1800 - loss: 0.0001157630467787385, # of mesh vertices: 38086, # of mesh faces: 76168
# Iteration 1900 - loss: 7.004675717325881e-05, # of mesh vertices: 38786, # of mesh faces: 77576
# Iteration 2000 - loss: 6.366003799485043e-05, # of mesh vertices: 38838, # of mesh faces: 77684
# Iteration 2100 - loss: 6.36363765806891e-05, # of mesh vertices: 38590, # of mesh faces: 77184
# Iteration 2200 - loss: 5.9951780713163316e-05, # of mesh vertices: 38772, # of mesh faces: 77552
# Iteration 2300 - loss: 5.945125303696841e-05, # of mesh vertices: 39042, # of mesh faces: 78096
# Iteration 2400 - loss: 6.774647044949234e-05, # of mesh vertices: 39208, # of mesh faces: 78416
# Iteration 2500 - loss: 5.586135375779122e-05, # of mesh vertices: 38936, # of mesh faces: 77888
# Iteration 2600 - loss: 5.5235686886589974e-05, # of mesh vertices: 39018, # of mesh faces: 78048
# Iteration 2700 - loss: 5.4183954489417374e-05, # of mesh vertices: 39086, # of mesh faces: 78184
# Iteration 2800 - loss: 5.805471300845966e-05, # of mesh vertices: 38896, # of mesh faces: 77808
# Iteration 2900 - loss: 5.3522515372605994e-05, # of mesh vertices: 39244, # of mesh faces: 78500
# Iteration 3000 - loss: 5.794308890472166e-05, # of mesh vertices: 38912, # of mesh faces: 77840
# Iteration 3100 - loss: 5.29264252691064e-05, # of mesh vertices: 39078, # of mesh faces: 78172
# Iteration 3200 - loss: 5.6123051763279364e-05, # of mesh vertices: 38898, # of mesh faces: 77808
# Iteration 3300 - loss: 5.313481960911304e-05, # of mesh vertices: 39128, # of mesh faces: 78268
# Iteration 3400 - loss: 4.926386463921517e-05, # of mesh vertices: 39344, # of mesh faces: 78700
# Iteration 3500 - loss: 4.940908547723666e-05, # of mesh vertices: 39224, # of mesh faces: 78460
# Iteration 3600 - loss: 4.946473200106993e-05, # of mesh vertices: 39188, # of mesh faces: 78388
# Iteration 3700 - loss: 5.0989066949114203e-05, # of mesh vertices: 39062, # of mesh faces: 78140
# Iteration 3800 - loss: 4.760586307384074e-05, # of mesh vertices: 39318, # of mesh faces: 78648
# Iteration 3900 - loss: 4.782768155564554e-05, # of mesh vertices: 39290, # of mesh faces: 78592
# Iteration 4000 - loss: 4.7843401262070984e-05, # of mesh vertices: 39262, # of mesh faces: 78536
# Iteration 4100 - loss: 4.785901910508983e-05, # of mesh vertices: 39354, # of mesh faces: 78716
# Iteration 4200 - loss: 4.6080604079179466e-05, # of mesh vertices: 39296, # of mesh faces: 78604
# Iteration 4300 - loss: 4.640938277589157e-05, # of mesh vertices: 39236, # of mesh faces: 78484
# Iteration 4400 - loss: 4.943840758642182e-05, # of mesh vertices: 39104, # of mesh faces: 78224
# Iteration 4500 - loss: 4.648925460060127e-05, # of mesh vertices: 39524, # of mesh faces: 79060
# Iteration 4600 - loss: 4.507293851929717e-05, # of mesh vertices: 39398, # of mesh faces: 78800
# Iteration 4700 - loss: 4.552765312837437e-05, # of mesh vertices: 39316, # of mesh faces: 78640
# Iteration 4800 - loss: 4.781164170708507e-05, # of mesh vertices: 39750, # of mesh faces: 79512
# Iteration 4900 - loss: 4.874743171967566e-05, # of mesh vertices: 39622, # of mesh faces: 79248
# Iteration 5000 - loss: 4.543991235550493e-05, # of mesh vertices: 39536, # of mesh faces: 79060
# Iteration 5100 - loss: 4.52154636150226e-05, # of mesh vertices: 39626, # of mesh faces: 79252
# Iteration 5200 - loss: 4.5472417696146294e-05, # of mesh vertices: 39636, # of mesh faces: 79280
# Iteration 5300 - loss: 4.3718242523027584e-05, # of mesh vertices: 39460, # of mesh faces: 78928
# Iteration 5400 - loss: 4.474735032999888e-05, # of mesh vertices: 39368, # of mesh faces: 78752
# Iteration 5500 - loss: 4.3399788410170004e-05, # of mesh vertices: 39588, # of mesh faces: 79176
# Iteration 5600 - loss: 4.355998680694029e-05, # of mesh vertices: 39604, # of mesh faces: 79216
# Iteration 5700 - loss: 4.371544491732493e-05, # of mesh vertices: 39640, # of mesh faces: 79284
# Iteration 5800 - loss: 4.331910167820752e-05, # of mesh vertices: 39552, # of mesh faces: 79104
# Iteration 5900 - loss: 4.335754056228325e-05, # of mesh vertices: 39410, # of mesh faces: 78840
# Iteration 6000 - loss: 4.314648685976863e-05, # of mesh vertices: 39428, # of mesh faces: 78876
# Iteration 6100 - loss: 4.241361966705881e-05, # of mesh vertices: 39558, # of mesh faces: 79124
# Iteration 6200 - loss: 4.203637217869982e-05, # of mesh vertices: 39488, # of mesh faces: 78992
# Iteration 6300 - loss: 4.25400648964569e-05, # of mesh vertices: 39462, # of mesh faces: 78944
# Iteration 6400 - loss: 4.195724250166677e-05, # of mesh vertices: 39594, # of mesh faces: 79208
# Iteration 6500 - loss: 4.1637256799731404e-05, # of mesh vertices: 39598, # of mesh faces: 79212
# Iteration 6600 - loss: 4.159592208452523e-05, # of mesh vertices: 39620, # of mesh faces: 79248
# Iteration 6700 - loss: 4.1667888581287116e-05, # of mesh vertices: 39658, # of mesh faces: 79328
# Iteration 6800 - loss: 4.1389801481273025e-05, # of mesh vertices: 39632, # of mesh faces: 79288
# Iteration 6900 - loss: 4.125176201341674e-05, # of mesh vertices: 39698, # of mesh faces: 79408
# Iteration 7000 - loss: 4.1507235437165946e-05, # of mesh vertices: 39552, # of mesh faces: 79108
# Iteration 7100 - loss: 4.0882798202801496e-05, # of mesh vertices: 39646, # of mesh faces: 79308
# Iteration 7200 - loss: 4.0835577237885445e-05, # of mesh vertices: 39576, # of mesh faces: 79160
# Iteration 7300 - loss: 4.101840022485703e-05, # of mesh vertices: 39662, # of mesh faces: 79348
# Iteration 7400 - loss: 4.1099105146713555e-05, # of mesh vertices: 39598, # of mesh faces: 79204
# Iteration 7500 - loss: 4.0780461858958006e-05, # of mesh vertices: 39556, # of mesh faces: 79112
# Iteration 7600 - loss: 4.060992068843916e-05, # of mesh vertices: 39590, # of mesh faces: 79184
# Iteration 7700 - loss: 4.018209074274637e-05, # of mesh vertices: 39640, # of mesh faces: 79272
# Iteration 7800 - loss: 4.052056101500057e-05, # of mesh vertices: 39690, # of mesh faces: 79388
# Iteration 7900 - loss: 4.020972482976504e-05, # of mesh vertices: 39618, # of mesh faces: 79240
# Iteration 8000 - loss: 4.038263068650849e-05, # of mesh vertices: 39622, # of mesh faces: 79240
# Iteration 8100 - loss: 4.009175245300867e-05, # of mesh vertices: 39708, # of mesh faces: 79424
# Iteration 8200 - loss: 4.0361162973567843e-05, # of mesh vertices: 39642, # of mesh faces: 79276
# Iteration 8300 - loss: 4.0358558180741966e-05, # of mesh vertices: 39666, # of mesh faces: 79328
# Iteration 8400 - loss: 4.021937638754025e-05, # of mesh vertices: 39756, # of mesh faces: 79516
# Iteration 8500 - loss: 3.974948049290106e-05, # of mesh vertices: 39668, # of mesh faces: 79336
# Iteration 8600 - loss: 4.025288944831118e-05, # of mesh vertices: 39640, # of mesh faces: 79284
# Iteration 8700 - loss: 3.956273212679662e-05, # of mesh vertices: 39738, # of mesh faces: 79476
# Iteration 8800 - loss: 3.989222022937611e-05, # of mesh vertices: 39664, # of mesh faces: 79324
# Iteration 8900 - loss: 3.9857950469013304e-05, # of mesh vertices: 39732, # of mesh faces: 79468
# Iteration 9000 - loss: 3.946273136534728e-05, # of mesh vertices: 39784, # of mesh faces: 79572
# Iteration 9100 - loss: 3.9406724681612104e-05, # of mesh vertices: 39674, # of mesh faces: 79348
# Iteration 9200 - loss: 3.967318480135873e-05, # of mesh vertices: 39684, # of mesh faces: 79364
# Iteration 9300 - loss: 3.958735760534182e-05, # of mesh vertices: 39730, # of mesh faces: 79464
# Iteration 9400 - loss: 3.9249447581823915e-05, # of mesh vertices: 39734, # of mesh faces: 79468
# Iteration 9500 - loss: 3.956751243094914e-05, # of mesh vertices: 39724, # of mesh faces: 79452
# Iteration 9600 - loss: 3.9379978261422366e-05, # of mesh vertices: 39776, # of mesh faces: 79556
# Iteration 9700 - loss: 3.9266898966161534e-05, # of mesh vertices: 39746, # of mesh faces: 79500
# Iteration 9800 - loss: 3.956330328946933e-05, # of mesh vertices: 39716, # of mesh faces: 79440
# Iteration 9900 - loss: 3.944423224311322e-05, # of mesh vertices: 39710, # of mesh faces: 79428
# Iteration 10000 - loss: 3.937484507332556e-05, # of mesh vertices: 39746, # of mesh faces: 79492
# Iteration 10100 - loss: 3.914037370122969e-05, # of mesh vertices: 39736, # of mesh faces: 79472
# Iteration 10200 - loss: 3.934621054213494e-05, # of mesh vertices: 39776, # of mesh faces: 79568
# Iteration 10300 - loss: 3.9071870560292155e-05, # of mesh vertices: 39770, # of mesh faces: 79540
# Iteration 10400 - loss: 3.906413621734828e-05, # of mesh vertices: 39782, # of mesh faces: 79560
# Iteration 10500 - loss: 3.8875004975125194e-05, # of mesh vertices: 39752, # of mesh faces: 79500
# Iteration 10600 - loss: 3.885137994075194e-05, # of mesh vertices: 39774, # of mesh faces: 79548
# Iteration 10700 - loss: 3.913588443538174e-05, # of mesh vertices: 39778, # of mesh faces: 79556
# Iteration 10800 - loss: 3.9079539419617504e-05, # of mesh vertices: 39810, # of mesh faces: 79624
# Iteration 10900 - loss: 3.8904436223674566e-05, # of mesh vertices: 39772, # of mesh faces: 79544
# Iteration 11000 - loss: 3.858361014863476e-05, # of mesh vertices: 39800, # of mesh faces: 79604
# Iteration 11100 - loss: 3.8791557017248124e-05, # of mesh vertices: 39740, # of mesh faces: 79488
# Iteration 11200 - loss: 3.906989877577871e-05, # of mesh vertices: 39836, # of mesh faces: 79676
# Iteration 11300 - loss: 3.9018155803205445e-05, # of mesh vertices: 39772, # of mesh faces: 79540
# Iteration 11400 - loss: 3.9126432966440916e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 11500 - loss: 3.876007394865155e-05, # of mesh vertices: 39788, # of mesh faces: 79584
# Iteration 11600 - loss: 3.883110184688121e-05, # of mesh vertices: 39770, # of mesh faces: 79552
# Iteration 11700 - loss: 3.849243512377143e-05, # of mesh vertices: 39814, # of mesh faces: 79628
# Iteration 11800 - loss: 3.889334766427055e-05, # of mesh vertices: 39794, # of mesh faces: 79592
# Iteration 11900 - loss: 3.9352660678559914e-05, # of mesh vertices: 39694, # of mesh faces: 79388
# Iteration 12000 - loss: 3.868369458359666e-05, # of mesh vertices: 39806, # of mesh faces: 79620
# Iteration 12100 - loss: 3.889246363542043e-05, # of mesh vertices: 39790, # of mesh faces: 79588
# Iteration 12200 - loss: 3.871774970320985e-05, # of mesh vertices: 39772, # of mesh faces: 79548
# Iteration 12300 - loss: 3.880342046613805e-05, # of mesh vertices: 39778, # of mesh faces: 79560
# Iteration 12400 - loss: 3.89037886634469e-05, # of mesh vertices: 39788, # of mesh faces: 79580
# Iteration 12500 - loss: 3.881567681673914e-05, # of mesh vertices: 39808, # of mesh faces: 79620
# Iteration 12600 - loss: 3.857204137602821e-05, # of mesh vertices: 39764, # of mesh faces: 79524
# Iteration 12700 - loss: 3.857486444758251e-05, # of mesh vertices: 39782, # of mesh faces: 79572
# Iteration 12800 - loss: 3.863187157548964e-05, # of mesh vertices: 39776, # of mesh faces: 79552
# Iteration 12900 - loss: 3.8703165046172217e-05, # of mesh vertices: 39818, # of mesh faces: 79644
# Iteration 13000 - loss: 3.836916948785074e-05, # of mesh vertices: 39778, # of mesh faces: 79564
# Iteration 13100 - loss: 3.8488738937303424e-05, # of mesh vertices: 39826, # of mesh faces: 79660
# Iteration 13200 - loss: 3.842603473458439e-05, # of mesh vertices: 39808, # of mesh faces: 79616
# Iteration 13300 - loss: 3.869206193485297e-05, # of mesh vertices: 39796, # of mesh faces: 79596
# Iteration 13400 - loss: 3.877927520079538e-05, # of mesh vertices: 39780, # of mesh faces: 79568
# Iteration 13500 - loss: 3.867153645842336e-05, # of mesh vertices: 39826, # of mesh faces: 79660
# Iteration 13600 - loss: 3.835644747596234e-05, # of mesh vertices: 39820, # of mesh faces: 79644
# Iteration 13700 - loss: 3.8643735024379566e-05, # of mesh vertices: 39820, # of mesh faces: 79640
# Iteration 13800 - loss: 3.838615521090105e-05, # of mesh vertices: 39790, # of mesh faces: 79580
# Iteration 13900 - loss: 3.845660830847919e-05, # of mesh vertices: 39842, # of mesh faces: 79688
# Iteration 14000 - loss: 3.8336162106134e-05, # of mesh vertices: 39788, # of mesh faces: 79580
# Iteration 14100 - loss: 3.8753627450205386e-05, # of mesh vertices: 39794, # of mesh faces: 79596
# Iteration 14200 - loss: 3.858094714814797e-05, # of mesh vertices: 39802, # of mesh faces: 79604
# Iteration 14300 - loss: 3.838117845589295e-05, # of mesh vertices: 39790, # of mesh faces: 79580
# Iteration 14400 - loss: 3.855450631817803e-05, # of mesh vertices: 39810, # of mesh faces: 79628
# Iteration 14500 - loss: 3.868393105221912e-05, # of mesh vertices: 39810, # of mesh faces: 79624
# Iteration 14600 - loss: 3.8709473301423714e-05, # of mesh vertices: 39834, # of mesh faces: 79676
# Iteration 14700 - loss: 3.856818511849269e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 14800 - loss: 3.845490573439747e-05, # of mesh vertices: 39764, # of mesh faces: 79540
# Iteration 14900 - loss: 3.84058803319931e-05, # of mesh vertices: 39802, # of mesh faces: 79608
# Iteration 15000 - loss: 3.8504411350004375e-05, # of mesh vertices: 39826, # of mesh faces: 79660
# Iteration 15100 - loss: 3.862672747345641e-05, # of mesh vertices: 39788, # of mesh faces: 79584
# Iteration 15200 - loss: 3.8761234463891014e-05, # of mesh vertices: 39790, # of mesh faces: 79584
# Iteration 15300 - loss: 3.8617479731328785e-05, # of mesh vertices: 39816, # of mesh faces: 79632
# Iteration 15400 - loss: 3.818617551587522e-05, # of mesh vertices: 39810, # of mesh faces: 79632
# Iteration 15500 - loss: 3.828210901701823e-05, # of mesh vertices: 39828, # of mesh faces: 79660
# Iteration 15600 - loss: 3.838870907202363e-05, # of mesh vertices: 39760, # of mesh faces: 79520
# Iteration 15700 - loss: 3.836345058516599e-05, # of mesh vertices: 39782, # of mesh faces: 79576
# Iteration 15800 - loss: 3.846231265924871e-05, # of mesh vertices: 39816, # of mesh faces: 79640
# Iteration 15900 - loss: 3.836038013105281e-05, # of mesh vertices: 39786, # of mesh faces: 79572
# Iteration 16000 - loss: 3.8330748793669045e-05, # of mesh vertices: 39806, # of mesh faces: 79620
# Iteration 16100 - loss: 3.821517020696774e-05, # of mesh vertices: 39798, # of mesh faces: 79600
# Iteration 16200 - loss: 3.816379467025399e-05, # of mesh vertices: 39810, # of mesh faces: 79620
# Iteration 16300 - loss: 3.8396297895815223e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 16400 - loss: 3.8219579437281936e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 16500 - loss: 3.863961683236994e-05, # of mesh vertices: 39800, # of mesh faces: 79604
# Iteration 16600 - loss: 3.8402926293201745e-05, # of mesh vertices: 39788, # of mesh faces: 79572
# Iteration 16700 - loss: 3.818704863078892e-05, # of mesh vertices: 39816, # of mesh faces: 79636
# Iteration 16800 - loss: 3.8068374124122784e-05, # of mesh vertices: 39814, # of mesh faces: 79636
# Iteration 16900 - loss: 3.8517446228070185e-05, # of mesh vertices: 39830, # of mesh faces: 79668
# Iteration 17000 - loss: 3.8531718018930405e-05, # of mesh vertices: 39810, # of mesh faces: 79620
# Iteration 17100 - loss: 3.8547266740351915e-05, # of mesh vertices: 39824, # of mesh faces: 79656
# Iteration 17200 - loss: 3.801213824772276e-05, # of mesh vertices: 39806, # of mesh faces: 79628
# Iteration 17300 - loss: 3.8514517655130476e-05, # of mesh vertices: 39780, # of mesh faces: 79556
# Iteration 17400 - loss: 3.831106732832268e-05, # of mesh vertices: 39792, # of mesh faces: 79584
# Iteration 17500 - loss: 3.825089515885338e-05, # of mesh vertices: 39824, # of mesh faces: 79656
# Iteration 17600 - loss: 3.8556299841729924e-05, # of mesh vertices: 39788, # of mesh faces: 79580
# Iteration 17700 - loss: 3.8615653465967625e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 17800 - loss: 3.8257770938798785e-05, # of mesh vertices: 39812, # of mesh faces: 79632
# Iteration 17900 - loss: 3.854570968542248e-05, # of mesh vertices: 39820, # of mesh faces: 79656
# Iteration 18000 - loss: 3.8421490899054334e-05, # of mesh vertices: 39786, # of mesh faces: 79576
# Iteration 18100 - loss: 3.858433774439618e-05, # of mesh vertices: 39812, # of mesh faces: 79636
# Iteration 18200 - loss: 3.8348913221852854e-05, # of mesh vertices: 39794, # of mesh faces: 79604
# Iteration 18300 - loss: 3.8508278521476313e-05, # of mesh vertices: 39792, # of mesh faces: 79588
# Iteration 18400 - loss: 3.8382509956136346e-05, # of mesh vertices: 39810, # of mesh faces: 79628
# Iteration 18500 - loss: 3.852400914183818e-05, # of mesh vertices: 39818, # of mesh faces: 79644
# Iteration 18600 - loss: 3.8332513213390484e-05, # of mesh vertices: 39816, # of mesh faces: 79640
# Iteration 18700 - loss: 3.835333700408228e-05, # of mesh vertices: 39824, # of mesh faces: 79656
# Iteration 18800 - loss: 3.83715087082237e-05, # of mesh vertices: 39790, # of mesh faces: 79580
# Iteration 18900 - loss: 3.828559420071542e-05, # of mesh vertices: 39808, # of mesh faces: 79624
# Iteration 19000 - loss: 3.8240497815422714e-05, # of mesh vertices: 39810, # of mesh faces: 79624
# Iteration 19100 - loss: 3.805678352364339e-05, # of mesh vertices: 39826, # of mesh faces: 79660
# Iteration 19200 - loss: 3.822087819571607e-05, # of mesh vertices: 39822, # of mesh faces: 79648
# Iteration 19300 - loss: 3.82781945518218e-05, # of mesh vertices: 39824, # of mesh faces: 79656
# Iteration 19400 - loss: 3.8386249798350036e-05, # of mesh vertices: 39792, # of mesh faces: 79584
# Iteration 19500 - loss: 3.824909799732268e-05, # of mesh vertices: 39816, # of mesh faces: 79640
# Iteration 19600 - loss: 3.839016426354647e-05, # of mesh vertices: 39816, # of mesh faces: 79640
# Iteration 19700 - loss: 3.8476791814900935e-05, # of mesh vertices: 39802, # of mesh faces: 79608
# Iteration 19800 - loss: 3.811230999417603e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 19900 - loss: 3.828093394986354e-05, # of mesh vertices: 39810, # of mesh faces: 79628
# Iteration 20000 - loss: 3.820349229499698e-05, # of mesh vertices: 39812, # of mesh faces: 79628
# Iteration 20100 - loss: 3.809353438555263e-05, # of mesh vertices: 39814, # of mesh faces: 79632
# Iteration 20200 - loss: 3.855925751850009e-05, # of mesh vertices: 39814, # of mesh faces: 79632
# Iteration 20300 - loss: 3.827457476290874e-05, # of mesh vertices: 39798, # of mesh faces: 79596
# Iteration 20400 - loss: 3.823124643531628e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 20500 - loss: 3.816270691459067e-05, # of mesh vertices: 39830, # of mesh faces: 79676
# Iteration 20600 - loss: 3.8118458178360015e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 20700 - loss: 3.803800791501999e-05, # of mesh vertices: 39808, # of mesh faces: 79624
# Iteration 20800 - loss: 3.8190646591829136e-05, # of mesh vertices: 39798, # of mesh faces: 79600
# Iteration 20900 - loss: 3.8223410228965804e-05, # of mesh vertices: 39822, # of mesh faces: 79652
# Iteration 21000 - loss: 3.823785300482996e-05, # of mesh vertices: 39794, # of mesh faces: 79604
# Iteration 21100 - loss: 3.8176513044163585e-05, # of mesh vertices: 39818, # of mesh faces: 79644
# Iteration 21200 - loss: 3.7985460949130356e-05, # of mesh vertices: 39822, # of mesh faces: 79652
# Iteration 21300 - loss: 3.808439214481041e-05, # of mesh vertices: 39806, # of mesh faces: 79616
# Iteration 21400 - loss: 3.839945566141978e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 21500 - loss: 3.833964728983119e-05, # of mesh vertices: 39816, # of mesh faces: 79640
# Iteration 21600 - loss: 3.836445102933794e-05, # of mesh vertices: 39806, # of mesh faces: 79616
# Iteration 21700 - loss: 3.8257832784438506e-05, # of mesh vertices: 39818, # of mesh faces: 79644
# Iteration 21800 - loss: 3.830842251772992e-05, # of mesh vertices: 39818, # of mesh faces: 79644
# Iteration 21900 - loss: 3.797607132582925e-05, # of mesh vertices: 39812, # of mesh faces: 79628
# Iteration 22000 - loss: 3.829919296549633e-05, # of mesh vertices: 39826, # of mesh faces: 79660
# Iteration 22100 - loss: 3.826302781817503e-05, # of mesh vertices: 39794, # of mesh faces: 79584
# Iteration 22200 - loss: 3.8162266719155014e-05, # of mesh vertices: 39812, # of mesh faces: 79636
# Iteration 22300 - loss: 3.8605023291893303e-05, # of mesh vertices: 39816, # of mesh faces: 79640
# Iteration 22400 - loss: 3.849541462841444e-05, # of mesh vertices: 39816, # of mesh faces: 79640
# Iteration 22500 - loss: 3.82504440494813e-05, # of mesh vertices: 39822, # of mesh faces: 79652
# Iteration 22600 - loss: 3.809431291301735e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 22700 - loss: 3.8075326301623136e-05, # of mesh vertices: 39824, # of mesh faces: 79656
# Iteration 22800 - loss: 3.8328973460011184e-05, # of mesh vertices: 39812, # of mesh faces: 79636
# Iteration 22900 - loss: 3.843135345960036e-05, # of mesh vertices: 39794, # of mesh faces: 79596
# Iteration 23000 - loss: 3.820306301349774e-05, # of mesh vertices: 39804, # of mesh faces: 79612
# Iteration 23100 - loss: 3.827327964245342e-05, # of mesh vertices: 39816, # of mesh faces: 79640
# Iteration 23200 - loss: 3.811937858699821e-05, # of mesh vertices: 39818, # of mesh faces: 79644
# Iteration 23300 - loss: 3.804609150392935e-05, # of mesh vertices: 39814, # of mesh faces: 79636
# Iteration 23400 - loss: 3.835256939055398e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 23500 - loss: 3.802197898039594e-05, # of mesh vertices: 39808, # of mesh faces: 79624
# Iteration 23600 - loss: 3.836749237962067e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 23700 - loss: 3.843715603579767e-05, # of mesh vertices: 39812, # of mesh faces: 79632
# Iteration 23800 - loss: 3.814698720816523e-05, # of mesh vertices: 39828, # of mesh faces: 79664
# Iteration 23900 - loss: 3.826886313618161e-05, # of mesh vertices: 39824, # of mesh faces: 79656
# Iteration 24000 - loss: 3.832035145023838e-05, # of mesh vertices: 39818, # of mesh faces: 79644
# Iteration 24100 - loss: 3.82039143005386e-05, # of mesh vertices: 39792, # of mesh faces: 79584
# Iteration 24200 - loss: 3.7945184885757044e-05, # of mesh vertices: 39806, # of mesh faces: 79620
# Iteration 24300 - loss: 3.810992348007858e-05, # of mesh vertices: 39818, # of mesh faces: 79644
# Iteration 24400 - loss: 3.821436985163018e-05, # of mesh vertices: 39812, # of mesh faces: 79632
# Iteration 24500 - loss: 3.85911698685959e-05, # of mesh vertices: 39796, # of mesh faces: 79600
# Iteration 24600 - loss: 3.824229497695342e-05, # of mesh vertices: 39822, # of mesh faces: 79652
# Iteration 24700 - loss: 3.813864532276057e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 24800 - loss: 3.850571738439612e-05, # of mesh vertices: 39824, # of mesh faces: 79656
# Iteration 24900 - loss: 3.838701741187833e-05, # of mesh vertices: 39796, # of mesh faces: 79600
# Iteration 25000 - loss: 3.8281763409031555e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 25100 - loss: 3.883888712152839e-05, # of mesh vertices: 39796, # of mesh faces: 79600
# Iteration 25200 - loss: 3.897877104463987e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 25300 - loss: 3.877361450577155e-05, # of mesh vertices: 39828, # of mesh faces: 79664
# Iteration 25400 - loss: 3.862052835756913e-05, # of mesh vertices: 39808, # of mesh faces: 79624
# Iteration 25500 - loss: 3.8924164982745424e-05, # of mesh vertices: 39812, # of mesh faces: 79632
# Iteration 25600 - loss: 3.89737579098437e-05, # of mesh vertices: 39790, # of mesh faces: 79588
# Iteration 25700 - loss: 3.893599932780489e-05, # of mesh vertices: 39812, # of mesh faces: 79632
# Iteration 25800 - loss: 3.894546898663975e-05, # of mesh vertices: 39806, # of mesh faces: 79620
# Iteration 25900 - loss: 3.897824717569165e-05, # of mesh vertices: 39824, # of mesh faces: 79656
# Iteration 26000 - loss: 3.887667480739765e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 26100 - loss: 3.8816324376966804e-05, # of mesh vertices: 39806, # of mesh faces: 79620
# Iteration 26200 - loss: 3.8687492633471265e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 26300 - loss: 3.878627103404142e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 26400 - loss: 3.866568295052275e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 26500 - loss: 3.872002343996428e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 26600 - loss: 3.902626849594526e-05, # of mesh vertices: 39806, # of mesh faces: 79620
# Iteration 26700 - loss: 3.871158332913183e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 26800 - loss: 3.8688933273078874e-05, # of mesh vertices: 39790, # of mesh faces: 79588
# Iteration 26900 - loss: 3.8976675568846986e-05, # of mesh vertices: 39790, # of mesh faces: 79588
# Iteration 27000 - loss: 3.888104038196616e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 27100 - loss: 3.90431669075042e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 27200 - loss: 3.8927664718357846e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 27300 - loss: 3.8652957300655544e-05, # of mesh vertices: 39792, # of mesh faces: 79592
# Iteration 27400 - loss: 3.8902799133211374e-05, # of mesh vertices: 39808, # of mesh faces: 79624
# Iteration 27500 - loss: 3.861418372252956e-05, # of mesh vertices: 39806, # of mesh faces: 79620
# Iteration 27600 - loss: 3.863670281134546e-05, # of mesh vertices: 39810, # of mesh faces: 79628
# Iteration 27700 - loss: 3.8773116102674976e-05, # of mesh vertices: 39808, # of mesh faces: 79624
# Iteration 27800 - loss: 3.9022535929689184e-05, # of mesh vertices: 39808, # of mesh faces: 79624
# Iteration 27900 - loss: 3.871509034070186e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 28000 - loss: 3.8781534385634586e-05, # of mesh vertices: 39790, # of mesh faces: 79588
# Iteration 28100 - loss: 3.879361611325294e-05, # of mesh vertices: 39794, # of mesh faces: 79596
# Iteration 28200 - loss: 3.862195444526151e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 28300 - loss: 3.8707345083821565e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 28400 - loss: 3.872294109896757e-05, # of mesh vertices: 39796, # of mesh faces: 79600
# Iteration 28500 - loss: 3.891674350597896e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 28600 - loss: 3.8946844142628834e-05, # of mesh vertices: 39812, # of mesh faces: 79632
# Iteration 28700 - loss: 3.889191066264175e-05, # of mesh vertices: 39812, # of mesh faces: 79632
# Iteration 28800 - loss: 3.873797686537728e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 28900 - loss: 3.879711948684417e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 29000 - loss: 3.8605259760515764e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 29100 - loss: 3.870423824992031e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 29200 - loss: 3.867952909786254e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 29300 - loss: 3.892658787663095e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 29400 - loss: 3.8777332520112395e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 29500 - loss: 3.902715616277419e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 29600 - loss: 3.87842083000578e-05, # of mesh vertices: 39812, # of mesh faces: 79632
# Iteration 29700 - loss: 3.859193384414539e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 29800 - loss: 3.8632842915831134e-05, # of mesh vertices: 39796, # of mesh faces: 79600
# Iteration 29900 - loss: 3.8576286897296086e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 30000 - loss: 3.867110353894532e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 30100 - loss: 3.892563108820468e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 30200 - loss: 3.905452831531875e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 30300 - loss: 3.8607897295150906e-05, # of mesh vertices: 39796, # of mesh faces: 79600
# Iteration 30400 - loss: 3.8933307223487645e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 30500 - loss: 3.8883448723936453e-05, # of mesh vertices: 39794, # of mesh faces: 79596
# Iteration 30600 - loss: 3.879746873280965e-05, # of mesh vertices: 39794, # of mesh faces: 79596
# Iteration 30700 - loss: 3.903424658346921e-05, # of mesh vertices: 39794, # of mesh faces: 79596
# Iteration 30800 - loss: 3.9077949622878805e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 30900 - loss: 3.905179983121343e-05, # of mesh vertices: 39810, # of mesh faces: 79628
# Iteration 31000 - loss: 3.8807080272817984e-05, # of mesh vertices: 39812, # of mesh faces: 79632
# Iteration 31100 - loss: 3.863107485813089e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 31200 - loss: 3.896029738825746e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 31300 - loss: 3.8981204852461815e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 31400 - loss: 3.894784094882198e-05, # of mesh vertices: 39794, # of mesh faces: 79596
# Iteration 31500 - loss: 3.8674159441143274e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 31600 - loss: 3.889241997967474e-05, # of mesh vertices: 39794, # of mesh faces: 79596
# Iteration 31700 - loss: 3.90317254641559e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 31800 - loss: 3.90864115615841e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 31900 - loss: 3.892736276611686e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 32000 - loss: 3.871082662953995e-05, # of mesh vertices: 39794, # of mesh faces: 79596
# Iteration 32100 - loss: 3.882114833686501e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 32200 - loss: 3.878939969581552e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 32300 - loss: 3.8732949178665876e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 32400 - loss: 3.875094625982456e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 32500 - loss: 3.880932490574196e-05, # of mesh vertices: 39794, # of mesh faces: 79596
# Iteration 32600 - loss: 3.8759833842050284e-05, # of mesh vertices: 39792, # of mesh faces: 79592
# Iteration 32700 - loss: 3.882664896082133e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 32800 - loss: 3.8749276427552104e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 32900 - loss: 3.906399797415361e-05, # of mesh vertices: 39796, # of mesh faces: 79600
# Iteration 33000 - loss: 3.888774517690763e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 33100 - loss: 3.8803002098575234e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 33200 - loss: 3.873645982821472e-05, # of mesh vertices: 39792, # of mesh faces: 79592
# Iteration 33300 - loss: 3.878585630445741e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 33400 - loss: 3.859406933770515e-05, # of mesh vertices: 39796, # of mesh faces: 79600
# Iteration 33500 - loss: 3.859981006826274e-05, # of mesh vertices: 39808, # of mesh faces: 79624
# Iteration 33600 - loss: 3.877221388393082e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 33700 - loss: 3.903074684785679e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 33800 - loss: 3.871630906360224e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 33900 - loss: 3.873381865560077e-05, # of mesh vertices: 39808, # of mesh faces: 79624
# Iteration 34000 - loss: 3.888830542564392e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 34100 - loss: 3.897363421856426e-05, # of mesh vertices: 39802, # of mesh faces: 79612
# Iteration 34200 - loss: 3.8797836168669164e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 34300 - loss: 3.8858066545799375e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 34400 - loss: 3.87590735044796e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 34500 - loss: 3.8653695810353383e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 34600 - loss: 3.8654594391118735e-05, # of mesh vertices: 39804, # of mesh faces: 79616
# Iteration 34700 - loss: 3.88221706089098e-05, # of mesh vertices: 39790, # of mesh faces: 79588
# Iteration 34800 - loss: 3.902212483808398e-05, # of mesh vertices: 39790, # of mesh faces: 79588
# Iteration 34900 - loss: 3.905158882844262e-05, # of mesh vertices: 39800, # of mesh faces: 79608
# Iteration 35000 - loss: 3.888050923706032e-05, # of mesh vertices: 39796, # of mesh faces: 79600
# Iteration 35100 - loss: 3.881511293002404e-05, # of mesh vertices: 39798, # of mesh faces: 79604
# Iteration 35200 - loss: 3.869499414577149e-05, # of mesh vertices: 39792, # of mesh faces: 79592
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       3 sdf, deform = pred[:,0], pred[:,1:]
#       4 verts_deformed = tet_verts + torch.tanh(deform) / grid_res # constraint deformation to avoid flipping tets
# ----> 5 mesh_verts, mesh_faces = kaolin.ops.conversions.marching_tetrahedra(verts_deformed.unsqueeze(0), tets, sdf.unsqueeze(0)) # running MT (batched) to extract surface mesh
#       6 mesh_verts, mesh_faces = mesh_verts[0], mesh_faces[0]
#       8 loss = loss_f(mesh_verts, mesh_faces, points, it)
#
# File ~/anaconda3/envs/pytorch3d/lib/python3.9/site-packages/kaolin/ops/conversions/tetmesh.py:164, in marching_tetrahedra(vertices, tets, sdf, return_tet_idx)
#     113 def marching_tetrahedra(vertices, tets, sdf, return_tet_idx=False):
#     114     r"""Convert discrete signed distance fields encoded on tetrahedral grids to triangle
#     115     meshes using marching tetrahedra algorithm as described in `An efficient method of
#     116     triangulating equi-valued surfaces by using tetrahedral cells`_. The output surface is differentiable with respect to
#    (...)
#     161             https://arxiv.org/abs/2111.04276
#     162     """
# --> 164     list_of_outputs = [_unbatched_marching_tetrahedra(vertices[b], tets, sdf[b], return_tet_idx) for b in range(vertices.shape[0])]
#     165     return list(zip(*list_of_outputs))
#
# File ~/anaconda3/envs/pytorch3d/lib/python3.9/site-packages/kaolin/ops/conversions/tetmesh.py:164, in <listcomp>(.0)
#     113 def marching_tetrahedra(vertices, tets, sdf, return_tet_idx=False):
#     114     r"""Convert discrete signed distance fields encoded on tetrahedral grids to triangle
#     115     meshes using marching tetrahedra algorithm as described in `An efficient method of
#     116     triangulating equi-valued surfaces by using tetrahedral cells`_. The output surface is differentiable with respect to
#    (...)
#     161             https://arxiv.org/abs/2111.04276
#     162     """
# --> 164     list_of_outputs = [_unbatched_marching_tetrahedra(vertices[b], tets, sdf[b], return_tet_idx) for b in range(vertices.shape[0])]
#     165     return list(zip(*list_of_outputs))
#
# File ~/anaconda3/envs/pytorch3d/lib/python3.9/site-packages/kaolin/ops/conversions/tetmesh.py:68, in _unbatched_marching_tetrahedra(vertices, tets, sdf, return_tet_idx)
#      66 occ_sum = torch.sum(occ_fx4, -1)
#      67 valid_tets = (occ_sum > 0) & (occ_sum < 4)
# ---> 68 occ_sum = occ_sum[valid_tets]
#      70 # find all vertices
#      71 all_edges = tets[valid_tets][:, base_tet_edges.to(device)].reshape(-1, 2)
#
# KeyboardInterrupt:

# %% [markdown]
# # Visualize Training
#
# You can now use [the Omniverse app](https://docs.omniverse.nvidia.com/app_kaolin/app_kaolin) to visualize the mesh optimization over training by using the training visualizer on "./logs/", where we stored the checkpoints.
#
# Alternatively, you can use [kaolin-dash3d](https://kaolin.readthedocs.io/en/latest/notes/checkpoints.html?highlight=usd#visualizing-with-kaolin-dash3d) to visualize the checkpoint by running <code>kaolin-dash3d --logdir=$logs_path --port=8080</code>. This command will launch a web server that will stream geometry to web clients. You can view the input point cloud and the reconstructed mesh at [localhost:8080](localhost:8080) as shown below. You can change the *global iteration* on the left to see how the mesh evolves during training.
#
# ![alt text](../samples/dash3d_mesh.png "Title")
# ![alt text](../samples/dash3d_pcd.png "Title")
